# %%
import cv2
import dlib
import os
import sys
import random
# 存储位置
output_dir = 'F:/picture/person/1xiaozhan'
size = 64
 
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
# 改变图片的亮度与对比度
 
def relight(img, light=1, bias=0):
    w = img.shape[1]
    h = img.shape[0]
    #image = []
    for i in range(0,w):
        for j in range(0,h):
            for c in range(3):
                tmp = int(img[j,i,c]*light + bias)
                if tmp > 255:
                    tmp = 255
                elif tmp < 0:
                    tmp = 0
                img[j,i,c] = tmp
    return img
 
#使用dlib自带的frontal_face_detector作为我们的特征提取器
detector = dlib.get_frontal_face_detector()
# 打开摄像头 参数为输入流，可以为摄像头或视频文件
#camera = cv2.VideoCapture(0)
camera = cv2.VideoCapture('F:/picture/xz/xz1/.mp4')

index = 1
while True:
    if (index <= 20):#存储20张人脸特征图像
        print('Being processed picture %s' % index)
        # 从摄像头读取照片
        success, img = camera.read()
        # 转为灰度图片
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # 使用detector进行人脸检测
        dets = detector(gray_img, 1)
 
        for i, d in enumerate(dets):
            x1 = d.top() if d.top() > 0 else 0
            y1 = d.bottom() if d.bottom() > 0 else 0
            x2 = d.left() if d.left() > 0 else 0
            y2 = d.right() if d.right() > 0 else 0
 
            face = img[x1:y1,x2:y2]
            # 调整图片的对比度与亮度， 对比度与亮度值都取随机数，这样能增加样本的多样性
            face = relight(face, random.uniform(0.5, 1.5), random.randint(-50, 50))
 
            face = cv2.resize(face, (size,size))
 
            cv2.imshow('image', face)
 
            cv2.imwrite(output_dir+'/'+str(index)+'.jpg', face)
 
            index += 1
        key = cv2.waitKey(30) & 0xff
        if key == 27:
            break
    else:
        print('Finished!')
        # 释放摄像头 release camera
        camera.release()
        # 删除建立的窗口 delete all the windows
        cv2.destroyAllWindows()
        break
# Out:
# Being processed picture 1
# Being processed picture 2
# Being processed picture 3
# Being processed picture 4
# Being processed picture 5
# Being processed picture 6
# Being processed picture 7
# Being processed picture 8
# Being processed picture 9
# Being processed picture 10
# Being processed picture 11
# Being processed picture 12
# Being processed picture 13
# Being processed picture 14
# Being processed picture 15
# Being processed picture 16
# Being processed picture 17
# Being processed picture 18
# Being processed picture 19
# Being processed picture 20
# Finished!

# %%
from cv2 import cv2 as cv2
import os
import dlib
from skimage import io
import csv
import numpy as np
 
# 要读取人脸图像文件的路径
path_images_from_camera = "F:/picture/person/"

# Dlib 正向人脸检测器
detector = dlib.get_frontal_face_detector()

# Dlib 人脸预测器
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# Dlib 人脸识别模型
# Face recognition model, the object maps human faces into 128D vectors
face_rec = dlib.face_recognition_model_v1("dlib_face_recognition_resnet_model_v1.dat")

# 返回单张图像的 128D 特征
def return_128d_features(path_img):
    img_rd = io.imread(path_img)
    #采取人脸特征数组，并写入文件夹F:/picture/features/631907060525/下
    s=path_img
    a=s[16:17]
    i1=str(a)
    a1=s[17:]
    str1="/"
    b=a1[a1.index(str1):-4]
    b1=b[1:]
    i2=str(b1)
    img_gray = cv2.cvtColor(img_rd, cv2.COLOR_BGR2RGB)
    faces = detector(img_gray, 1)
    for i in range(len(faces)):
        landmarks = np.matrix([[p.x, p.y] for p in predictor(img_rd,faces[i]).parts()])  
        for idx, point in enumerate(landmarks):
            # 68点的坐标
            pos = (point[0, 0], point[0, 1])
            add="F:/picture/features/631907060525/face"+i1+"_feature"+i2+".csv"
            with open(add, "a", newline="") as csvfile:
                writer1 = csv.writer(csvfile)
                writer1.writerow((idx,pos))
        print(add)

    print("%-40s %-20s" % ("检测到人脸的图像 / image with faces detected:", path_img), '\n')

    # 因为有可能截下来的人脸再去检测，检测不出来人脸了
    # 所以要确保是 检测到人脸的人脸图像 拿去算特征
    if len(faces) != 0:
        shape = predictor(img_gray, faces[0])
        face_descriptor = face_rec.compute_face_descriptor(img_gray, shape)
    else:
        face_descriptor = 0
        print("no face")

    return face_descriptor


# 将文件夹中照片特征提取出来, 写入 CSV
def return_features_mean_personX(path_faces_personX):
    features_list_personX = []
    photos_list = os.listdir(path_faces_personX)
    if photos_list:
        for i in range(len(photos_list)):
            # 调用return_128d_features()得到128d特征
            print("%-40s %-20s" % ("正在读的人脸图像 / image to read:", path_faces_personX + "/" + photos_list[i]))
            features_128d = return_128d_features(path_faces_personX + "/" + photos_list[i])
            #  print(features_128d)
            # 遇到没有检测出人脸的图片跳过
            if features_128d == 0:
                i += 1
            else:
                features_list_personX.append(features_128d)
                i1=str(i+1)
                add="F:/picture/features/tz/face_feature"+i1+".csv"
                print(add)
                with open(add, "w", newline="") as csvfile:
                    writer1 = csv.writer(csvfile)
                    writer1.writerow(features_128d)

    else:
        print("文件夹内图像文件为空 / Warning: No images in " + path_faces_personX + '/', '\n')

    # 计算 128D 特征的均值
    # N x 128D -> 1 x 128D
    if features_list_personX:
        features_mean_personX = np.array(features_list_personX).mean(axis=0)
    else:
        features_mean_personX = '0'

    return features_mean_personX


# 读取某人所有的人脸图像的数据
people = os.listdir(path_images_from_camera)
people.sort()
with open("F:/picture/features/features2_all.csv", "w", newline="") as csvfile: #程序会新建一个表格文件来保存特征值，方便以后比对
    writer = csv.writer(csvfile)
    for person in people:
        print("##### " + person + " #####")
        # Get the mean/average features of face/personX, it will be a list with a length of 128D
        features_mean_personX = return_features_mean_personX(path_images_from_camera + person)
        writer.writerow(features_mean_personX)
        print("特征均值 / The mean of features:", list(features_mean_personX))
        print('\n')
    print("所有录入人脸数据存入 / Save all the features of faces registered into:F:/picture/features/features2_all.csv")
# Out:
# ##### 1xiaozhan #####
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/1.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/1.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan/1.jpg
#
# F:/picture/features/tz/face_feature1.csv
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/10.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/10.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan/10.jpg
#
# F:/picture/features/tz/face_feature2.csv
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/11.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/11.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan/11.jpg
#
# F:/picture/features/tz/face_feature3.csv
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/12.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/12.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan/12.jpg
#
# F:/picture/features/tz/face_feature4.csv
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/13.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/13.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan/13.jpg
#
# F:/picture/features/tz/face_feature5.csv
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/14.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/14.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan/14.jpg
#
# F:/picture/features/tz/face_feature6.csv
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/15.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/15.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan/15.jpg
#
# F:/picture/features/tz/face_feature7.csv
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/16.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/16.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan/16.jpg
#
# F:/picture/features/tz/face_feature8.csv
# 正在读的人脸图像 / image to read:                F:/picture/person/1xiaozhan/17.jpg
# F:/picture/features/631907060525/facen_feature1xiaozhan/17.csv
# 检测到人脸的图像 / image with faces detected:    F:/picture/person/1xiaozhan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-b29aa2dcec7c> in <module>
#     100         print("##### " + person + " #####")
#     101         # Get the mean/average features of face/personX, it will be a list with a length of 128D
# --> 102         features_mean_personX = return_features_mean_personX(path_images_from_camera + person)
#     103         writer.writerow(features_mean_personX)
#     104         print("特征均值 / The mean of features:", list(features_mean_personX))
#
# <ipython-input-31-b29aa2dcec7c> in return_features_mean_personX(path_faces_personX)
#      65             # 调用return_128d_features()得到128d特征
#      66             print("%-40s %-20s" % ("正在读的人脸图像 / image to read:", path_faces_personX + "/" + photos_list[i]))
# ---> 67             features_128d = return_128d_features(path_faces_personX + "/" + photos_list[i])
#      68             #  print(features_128d)
#      69             # 遇到没有检测出人脸的图片跳过
#
# <ipython-input-31-b29aa2dcec7c> in return_128d_features(path_img)
#      21 # 返回单张图像的 128D 特征
#      22 def return_128d_features(path_img):
# ---> 23     img_rd = io.imread(path_img)
#      24     s=path_img
#      25     a=s[16:17]
#
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_plugins\imageio_plugin.py in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ---> 10     return np.asarray(imageio_imread(*args, **kwargs))
#
# C:\ProgramData\Anaconda3\lib\site-packages\imageio\core\functions.py in imread(uri, format, **kwargs)
#     263
#     264     # Get reader and read first
# --> 265     reader = read(uri, format, "i", **kwargs)
#     266     with reader:
#     267         return reader.get_data(0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\imageio\core\functions.py in get_reader(uri, format, mode, **kwargs)
#     179     if format is None:
#     180         modename = MODENAMES.get(mode, mode)
# --> 181         raise ValueError(
#     182             "Could not find a format to read the specified file in %s mode" % modename
#     183         )
#
# ValueError: Could not find a format to read the specified file in single-image mode

# %%
# 摄像头实时人脸识别
import os
import winsound # 系统音效
from playsound import playsound # 音频播放
import dlib          # 人脸处理的库 Dlib
import csv # 存入表格
import time
import sys
import numpy as np   # 数据处理的库 numpy
from cv2 import cv2 as cv2           # 图像处理的库 OpenCv
import pandas as pd  # 数据处理的库 Pandas


# 人脸识别模型，提取128D的特征矢量
# face recognition model, the object maps human faces into 128D vectors
# Refer this tutorial: http://dlib.net/python/index.html#dlib.face_recognition_model_v1
facerec = dlib.face_recognition_model_v1("dlib_face_recognition_resnet_model_v1.dat")


# 计算两个128D向量间的欧式距离
# compute the e-distance between two 128D features
def return_euclidean_distance(feature_1, feature_2):
    feature_1 = np.array(feature_1)
    feature_2 = np.array(feature_2)
    dist = np.sqrt(np.sum(np.square(feature_1 - feature_2)))
    return dist


# 处理存放所有人脸特征的 csv
path_features_known_csv = "F:/picture/features/features2_all.csv"
csv_rd = pd.read_csv(path_features_known_csv, header=None)


# 用来存放所有录入人脸特征的数组
# the array to save the features of faces in the database
features_known_arr = []

# 读取已知人脸数据
# print known faces
for i in range(csv_rd.shape[0]):
    features_someone_arr = []
    for j in range(0, len(csv_rd.iloc[i, :])):
        features_someone_arr.append(csv_rd.iloc[i, :][j])
    features_known_arr.append(features_someone_arr)
print("Faces in Database：", len(features_known_arr))

# Dlib 检测器和预测器
# The detector and predictor will be used
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

# 创建 cv2 摄像头对象
# cv2.VideoCapture(0) to use the default camera of PC,
# and you can use local video name by use cv2.VideoCapture(filename)
cap = cv2.VideoCapture(0)

# cap.set(propId, value)
# 设置视频参数，propId 设置的视频参数，value 设置的参数值
cap.set(3, 480)

# cap.isOpened() 返回 true/false 检查初始化是否成功
# when the camera is open
while cap.isOpened():

    flag, img_rd = cap.read()
    kk = cv2.waitKey(1)

    # 取灰度
    img_gray = cv2.cvtColor(img_rd, cv2.COLOR_RGB2GRAY)

    # 人脸数 faces
    faces = detector(img_gray, 0)

    # 待会要写的字体 font to write later
    font = cv2.FONT_HERSHEY_COMPLEX

    # 存储当前摄像头中捕获到的所有人脸的坐标/名字
    # the list to save the positions and names of current faces captured
    pos_namelist = []
    name_namelist = []

    # 按下 q 键退出
    # press 'q' to exit
    if kk == ord('q'):
        break
    else:
        # 检测到人脸 when face detected
        if len(faces) != 0:  
            # 获取当前捕获到的图像的所有人脸的特征，存储到 features_cap_arr
            # get the features captured and save into features_cap_arr
            features_cap_arr = []
            for i in range(len(faces)):
                shape = predictor(img_rd, faces[i])
                features_cap_arr.append(facerec.compute_face_descriptor(img_rd, shape))

            # 遍历捕获到的图像中所有的人脸
            # traversal all the faces in the database
            for k in range(len(faces)):
                print("##### camera person", k+1, "#####")
                # 让人名跟随在矩形框的下方
                # 确定人名的位置坐标
                # 先默认所有人不认识，是 unknown
                # set the default names of faces with "unknown"
                name_namelist.append("unknown")

                # 每个捕获人脸的名字坐标 the positions of faces captured
                pos_namelist.append(tuple([faces[k].left(), int(faces[k].bottom() + (faces[k].bottom() - faces[k].top())/4)]))

                # 对于某张人脸，遍历所有存储的人脸特征
                # for every faces detected, compare the faces in the database
                e_distance_list = []
                for i in range(len(features_known_arr)):
                    # 如果 person_X 数据不为空
                    if str(features_known_arr[i][0]) != '0.0':
                        print("with person", str(i + 1), "the e distance: ", end='')
                        e_distance_tmp = return_euclidean_distance(features_cap_arr[k], features_known_arr[i])
                        print(e_distance_tmp)
                        e_distance_list.append(e_distance_tmp)
                    else:
                        # 空数据 person_X
                        e_distance_list.append(999999999)
                # 找出最接近的一个人脸数据是第几个
                # Find the one with minimum e distance
                similar_person_num = e_distance_list.index(min(e_distance_list))
                print("Minimum e distance with person", int(similar_person_num)+1)
                
                # 计算人脸识别特征与数据集特征的欧氏距离
                # 距离小于0.4则标出为可识别人物
                if min(e_distance_list) < 0.4:
                    # 这里可以修改摄像头中标出的人名
                    # Here you can modify the names shown on the camera
                    # 1、遍历文件夹目录
                    folder_name = 'F:/picture/person'
                    # 最接近的人脸
                    sum=similar_person_num+1
                    key_id=1 # 从第一个人脸数据文件夹进行对比
                    # 获取文件夹中的文件名:1wang、2zhou、3...
                    file_names = os.listdir(folder_name)
                    for name in file_names:
                        # print(name+'->'+str(key_id))
                        if sum ==key_id:
                            #winsound.Beep(300,500)# 响铃：300频率，500持续时间
                            name_namelist[k] = name[1:]#人名删去第一个数字（用于视频输出标识）
                        key_id += 1
                    # 播放欢迎光临音效
                    #playsound('D:/myworkspace/JupyterNotebook/People/music/welcome.wav')
                    # print("May be person "+str(int(similar_person_num)+1))
                    # -----------筛选出人脸并保存到visitor文件夹------------
                    for i, d in enumerate(faces):
                        x1 = d.top() if d.top() > 0 else 0
                        y1 = d.bottom() if d.bottom() > 0 else 0
                        x2 = d.left() if d.left() > 0 else 0
                        y2 = d.right() if d.right() > 0 else 0
                        face = img_rd[x1:y1,x2:y2]
                        size = 64
                        face = cv2.resize(face, (size,size))
                        # 要存储visitor人脸图像文件的路径
                        path_visitors_save_dir = "F:/picture/person/visitor/known"
                        # 存储格式：2019-06-24-14-33-40wang.jpg
                        now_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
                        save_name = str(now_time)+str(name_namelist[k])+'.jpg'
                        # print(save_name)
                        # 本次图片保存的完整url
                        save_path = path_visitors_save_dir+'/'+ save_name    
                        # 遍历visitor文件夹所有文件名
                        visitor_names = os.listdir(path_visitors_save_dir)
                        visitor_name=''
                        for name in visitor_names:
                            # 名字切片到分钟数：2019-06-26-11-33-00wangyu.jpg
                            visitor_name=(name[0:16]+'-00'+name[19:])
                        # print(visitor_name)
                        visitor_save=(save_name[0:16]+'-00'+save_name[19:])
                        # print(visitor_save)
                        # 一分钟之内重复的人名不保存
                        if visitor_save!=visitor_name:
                            cv2.imwrite(save_path, face)
                            print('新存储：'+path_visitors_save_dir+'/'+str(now_time)+str(name_namelist[k])+'.jpg')
                        else:
                            print('重复，未保存！')
                            
                else:
                    # 播放无法识别音效
                    #playsound('D:/myworkspace/JupyterNotebook/People/music/sorry.wav')
                    print("Unknown person")
                    # -----保存图片-------
                    # -----------筛选出人脸并保存到visitor文件夹------------
                    for i, d in enumerate(faces):
                        x1 = d.top() if d.top() > 0 else 0
                        y1 = d.bottom() if d.bottom() > 0 else 0
                        x2 = d.left() if d.left() > 0 else 0
                        y2 = d.right() if d.right() > 0 else 0
                        face = img_rd[x1:y1,x2:y2]
                        size = 64
                        face = cv2.resize(face, (size,size))
                        # 要存储visitor-》unknown人脸图像文件的路径
                        path_visitors_save_dir = "F:/picture/person/visitor/unknown"
                        # 存储格式：2019-06-24-14-33-40unknown.jpg
                        now_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
                        # print(save_name)
                        # 本次图片保存的完整url
                        save_path = path_visitors_save_dir+'/'+ str(now_time)+'unknown.jpg'
                        cv2.imwrite(save_path, face)
                        print('新存储：'+path_visitors_save_dir+'/'+str(now_time)+'unknown.jpg')
                
                # 矩形框
                # draw rectangle
                for kk, d in enumerate(faces):
                    # 绘制矩形框
                    cv2.rectangle(img_rd, tuple([d.left(), d.top()]), tuple([d.right(), d.bottom()]), (0, 255, 255), 2)
                print('\n')

            # 在人脸框下面写人脸名字
            # write names under rectangle
            for i in range(len(faces)):
                cv2.putText(img_rd, name_namelist[i], pos_namelist[i], font, 0.8, (0, 255, 255), 1, cv2.LINE_AA)

    print("Faces in camera now:", name_namelist, "\n")

    #cv2.putText(img_rd, "Press 'q': Quit", (20, 450), font, 0.8, (84, 255, 159), 1, cv2.LINE_AA)
    cv2.putText(img_rd, "Face Recognition", (20, 40), font, 1, (0, 0, 255), 1, cv2.LINE_AA)
    cv2.putText(img_rd, "Visitors: " + str(len(faces)), (20, 100), font, 1, (0, 0, 255), 1, cv2.LINE_AA)

    # 窗口显示 show with opencv
    cv2.imshow("camera", img_rd)
    key = cv2.waitKey(1) & 0xFF
    #退出程序
    if key == ord("q"):
        break
    # 开始程序
    if key == ord("d"):
        dealing = not dealing

# 释放摄像头 release camera
cap.release()

# 删除建立的窗口 delete all the windows
cv2.destroyAllWindows()
# Out:
# Faces in Database： 5
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4491480025335778
# with person 2 the e distance: 0.5596323204195731
# with person 3 the e distance: 0.4197971637354044
# with person 4 the e distance: 0.5034518156262092
# with person 5 the e distance: 0.5261578820978536
# Minimum e distance with person 3
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-10unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.44722654466428663
# with person 2 the e distance: 0.5828077750646068
# with person 3 the e distance: 0.5011150955794241
# with person 4 the e distance: 0.5756628123121967
# with person 5 the e distance: 0.5455244732522889
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-10unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.501746030053266
# with person 2 the e distance: 0.4568675446185229
# with person 3 the e distance: 0.461900551218118
# with person 4 the e distance: 0.5824873369892738
# with person 5 the e distance: 0.6339247982011519
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-11unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.37102390633519616
# with person 2 the e distance: 0.43422775131678204
# with person 3 the e distance: 0.38383809156809173
# with person 4 the e distance: 0.4655129707664888
# with person 5 the e distance: 0.5142312327449193
# Minimum e distance with person 1
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-11xiaozhan.jpg
#
#
# Faces in camera now: ['xiaozhan']
# ##### camera person 1 #####
# with person 1 the e distance: 0.38610558426377745
# with person 2 the e distance: 0.40483824833445636
# with person 3 the e distance: 0.38480894830720364
# with person 4 the e distance: 0.4998891097218244
# with person 5 the e distance: 0.5582261064480962
# Minimum e distance with person 3
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-12houminghao.jpg
#
#
# Faces in camera now: ['houminghao']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3974797369004592
# with person 2 the e distance: 0.4948614788728586
# with person 3 the e distance: 0.418609082059608
# with person 4 the e distance: 0.501408297548593
# with person 5 the e distance: 0.5582043398530503
# Minimum e distance with person 1
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-12xiaozhan.jpg
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3799232177751714
# with person 2 the e distance: 0.5702141662122898
# with person 3 the e distance: 0.5406453042451894
# with person 4 the e distance: 0.48539426025965376
# with person 5 the e distance: 0.6110750365712917
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35737213476972907
# with person 2 the e distance: 0.5820973769395709
# with person 3 the e distance: 0.502095286155177
# with person 4 the e distance: 0.45402436373854166
# with person 5 the e distance: 0.6246242911791228
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3860453302171006
# with person 2 the e distance: 0.5662207776576347
# with person 3 the e distance: 0.48958757432206357
# with person 4 the e distance: 0.4633037978645317
# with person 5 the e distance: 0.617437448228848
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36324201348547913
# with person 2 the e distance: 0.5537139771882976
# with person 3 the e distance: 0.47360841617445204
# with person 4 the e distance: 0.4688880912407815
# with person 5 the e distance: 0.5930832687244129
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.43973339751087753
# with person 2 the e distance: 0.47738956036370356
# with person 3 the e distance: 0.44558957437586705
# with person 4 the e distance: 0.49249916466768767
# with person 5 the e distance: 0.571678278202055
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-14unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.38502493115160685
# with person 2 the e distance: 0.5459879850752771
# with person 3 the e distance: 0.44931300056510487
# with person 4 the e distance: 0.4707184063074578
# with person 5 the e distance: 0.5659965612365077
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3790957228744806
# with person 2 the e distance: 0.5358564433305382
# with person 3 the e distance: 0.45329954864438216
# with person 4 the e distance: 0.46383044375254734
# with person 5 the e distance: 0.5845024182294132
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3856855115343901
# with person 2 the e distance: 0.5730658174916493
# with person 3 the e distance: 0.4945369520548724
# with person 4 the e distance: 0.4545047908497272
# with person 5 the e distance: 0.5530954340025078
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4375326976551185
# with person 2 the e distance: 0.5232458138411687
# with person 3 the e distance: 0.5278997609700683
# with person 4 the e distance: 0.5078844811054237
# with person 5 the e distance: 0.5787508187782665
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-16unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3605510960265737
# with person 2 the e distance: 0.4723570851370157
# with person 3 the e distance: 0.4579693173615479
# with person 4 the e distance: 0.45174857490478837
# with person 5 the e distance: 0.5372886298730287
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36607569407427715
# with person 2 the e distance: 0.5812374356491223
# with person 3 the e distance: 0.4762442986852176
# with person 4 the e distance: 0.47014442064812323
# with person 5 the e distance: 0.5309784937885185
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.42171412460701074
# with person 2 the e distance: 0.4849415637679338
# with person 3 the e distance: 0.4249441659077903
# with person 4 the e distance: 0.4467777618242422
# with person 5 the e distance: 0.5541827357486603
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-17unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4027732101106045
# with person 2 the e distance: 0.4538535292224336
# with person 3 the e distance: 0.4049185212606202
# with person 4 the e distance: 0.4549956427082631
# with person 5 the e distance: 0.545040922245022
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-17unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3930391676048627
# with person 2 the e distance: 0.3863775154642596
# with person 3 the e distance: 0.37517948820678987
# with person 4 the e distance: 0.459631170401706
# with person 5 the e distance: 0.5526024329984931
# Minimum e distance with person 3
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-17houminghao.jpg
#
#
# Faces in camera now: ['houminghao']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3958879254865539
# with person 2 the e distance: 0.4407405530735212
# with person 3 the e distance: 0.3978659524211359
# with person 4 the e distance: 0.4451816193079542
# with person 5 the e distance: 0.5323687919246988
# Minimum e distance with person 1
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-18xiaozhan.jpg
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3964908106075399
# with person 2 the e distance: 0.425040312155159
# with person 3 the e distance: 0.38526852048007926
# with person 4 the e distance: 0.44280397736079424
# with person 5 the e distance: 0.5330398201988621
# Minimum e distance with person 3
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-18houminghao.jpg
#
#
# Faces in camera now: ['houminghao']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4147892594460194
# with person 2 the e distance: 0.4724835768596253
# with person 3 the e distance: 0.42329645873176175
# with person 4 the e distance: 0.4585107925102587
# with person 5 the e distance: 0.5476625547345605
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-19unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.37080488026468134
# with person 2 the e distance: 0.5134110768207382
# with person 3 the e distance: 0.4409450874534275
# with person 4 the e distance: 0.454422187135137
# with person 5 the e distance: 0.5854020463694728
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3432012736857545
# with person 2 the e distance: 0.5424384044470331
# with person 3 the e distance: 0.450803280474503
# with person 4 the e distance: 0.45835966991903593
# with person 5 the e distance: 0.5346521091429348
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.31475144107772146
# with person 2 the e distance: 0.5376672995507172
# with person 3 the e distance: 0.47181605099950125
# with person 4 the e distance: 0.42997007121206093
# with person 5 the e distance: 0.5213503469255183
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
# ##### camera person 1 #####
# with person 1 the e distance: 0.4137683784239036
# with person 2 the e distance: 0.5018034085408144
# with person 3 the e distance: 0.44006027961165456
# with person 4 the e distance: 0.4349166482286558
# with person 5 the e distance: 0.5612564595474434
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-20unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4446229341815888
# with person 2 the e distance: 0.4332681022425936
# with person 3 the e distance: 0.39139306952755704
# with person 4 the e distance: 0.5158698943944319
# with person 5 the e distance: 0.5897012281307561
# Minimum e distance with person 3
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-21houminghao.jpg
#
#
# Faces in camera now: ['houminghao']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3956546456664284
# with person 2 the e distance: 0.4014172456737278
# with person 3 the e distance: 0.42034421440223846
# with person 4 the e distance: 0.48730996490871936
# with person 5 the e distance: 0.5933811134449133
# Minimum e distance with person 1
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-21xiaozhan.jpg
#
#
# Faces in camera now: ['xiaozhan']
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.49936752325150857
# with person 2 the e distance: 0.46658463794343696
# with person 3 the e distance: 0.4549419260195451
# with person 4 the e distance: 0.6105302914254884
# with person 5 the e distance: 0.5798902112555682
# Minimum e distance with person 3
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-23unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4261831279868032
# with person 2 the e distance: 0.6168347430328932
# with person 3 the e distance: 0.5436507049449599
# with person 4 the e distance: 0.5495439124140215
# with person 5 the e distance: 0.5441829012936357
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-23unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4311251125024808
# with person 2 the e distance: 0.597871676562881
# with person 3 the e distance: 0.5615822187893847
# with person 4 the e distance: 0.584771790775606
# with person 5 the e distance: 0.6134298680636134
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-23unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3341135573436649
# with person 2 the e distance: 0.5562882208984659
# with person 3 the e distance: 0.4767882378451952
# with person 4 the e distance: 0.45215399586074695
# with person 5 the e distance: 0.573030159471458
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35931180093134235
# with person 2 the e distance: 0.5298581018458717
# with person 3 the e distance: 0.4526003819449675
# with person 4 the e distance: 0.46473527490843963
# with person 5 the e distance: 0.5534155106745301
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36547243637899046
# with person 2 the e distance: 0.4728703213240222
# with person 3 the e distance: 0.40377588303611045
# with person 4 the e distance: 0.429293523034841
# with person 5 the e distance: 0.5339757801001335
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.37888465967206597
# with person 2 the e distance: 0.4864810580000871
# with person 3 the e distance: 0.42540532204738574
# with person 4 the e distance: 0.44710486945219313
# with person 5 the e distance: 0.5489444501050657
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3624836297052907
# with person 2 the e distance: 0.45649487032458513
# with person 3 the e distance: 0.4190466169342915
# with person 4 the e distance: 0.43716710935986963
# with person 5 the e distance: 0.5149236395337745
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3613332591190855
# with person 2 the e distance: 0.5302292032140462
# with person 3 the e distance: 0.45676243593207927
# with person 4 the e distance: 0.45617597672883603
# with person 5 the e distance: 0.6027786139917516
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34859489505747315
# with person 2 the e distance: 0.538650499378552
# with person 3 the e distance: 0.45862356341880617
# with person 4 the e distance: 0.45190982086746107
# with person 5 the e distance: 0.5816740767682462
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34901358974087754
# with person 2 the e distance: 0.556540240831927
# with person 3 the e distance: 0.4849454267565362
# with person 4 the e distance: 0.4426146565085244
# with person 5 the e distance: 0.5411077327639554
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3408024947085049
# with person 2 the e distance: 0.555719415718672
# with person 3 the e distance: 0.48055150464646024
# with person 4 the e distance: 0.4440622078011802
# with person 5 the e distance: 0.5495652360800116
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36183486968488987
# with person 2 the e distance: 0.5609202145971317
# with person 3 the e distance: 0.48499842314540437
# with person 4 the e distance: 0.4489577357341539
# with person 5 the e distance: 0.5641993540933136
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.42463298001803557
# with person 2 the e distance: 0.4722855340576783
# with person 3 the e distance: 0.440223400800248
# with person 4 the e distance: 0.44499468169783635
# with person 5 the e distance: 0.5267383758590238
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-28unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.48669377120470203
# with person 2 the e distance: 0.39421921303823
# with person 3 the e distance: 0.45106299788876775
# with person 4 the e distance: 0.5553718291588912
# with person 5 the e distance: 0.6577001272026523
# Minimum e distance with person 2
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-28dilireba.jpg
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.43751167283072256
# with person 2 the e distance: 0.3737320032842703
# with person 3 the e distance: 0.4126937229330333
# with person 4 the e distance: 0.502314646054096
# with person 5 the e distance: 0.5856679721993139
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.43354924348367785
# with person 2 the e distance: 0.36274040408609437
# with person 3 the e distance: 0.41384233201078136
# with person 4 the e distance: 0.5055166683534111
# with person 5 the e distance: 0.5936748142378202
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.507804564662693
# with person 2 the e distance: 0.41413582841195307
# with person 3 the e distance: 0.47000519487100995
# with person 4 the e distance: 0.5624953402125907
# with person 5 the e distance: 0.653896029868419
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-29unknown.jpg
#
#
# Faces in camera now: ['unknown']
# ##### camera person 1 #####
# with person 1 the e distance: 0.5004841261947555
# with person 2 the e distance: 0.4005675645598568
# with person 3 the e distance: 0.4658636194770476
# with person 4 the e distance: 0.558462054041286
# with person 5 the e distance: 0.6529776461804646
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-30unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4840430954981837
# with person 2 the e distance: 0.4053932472966817
# with person 3 the e distance: 0.4626278624169244
# with person 4 the e distance: 0.5398203913187102
# with person 5 the e distance: 0.6366083728411011
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-30unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4782257375821887
# with person 2 the e distance: 0.403307631614791
# with person 3 the e distance: 0.4590823217302211
# with person 4 the e distance: 0.5380082092462825
# with person 5 the e distance: 0.6325587168466034
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-31unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4732107789251213
# with person 2 the e distance: 0.4127520213494399
# with person 3 the e distance: 0.4522060040193985
# with person 4 the e distance: 0.5423188629523784
# with person 5 the e distance: 0.6251930167933063
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-31unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.47157374889876436
# with person 2 the e distance: 0.4110197626669603
# with person 3 the e distance: 0.4630677518739454
# with person 4 the e distance: 0.5405555971564516
# with person 5 the e distance: 0.6249272278945911
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-31unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.46497202963321466
# with person 2 the e distance: 0.4026773457917303
# with person 3 the e distance: 0.4510920054473475
# with person 4 the e distance: 0.5439111565324191
# with person 5 the e distance: 0.6169196234374689
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-32unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.47370487126360444
# with person 2 the e distance: 0.4074017994966189
# with person 3 the e distance: 0.4586802414245798
# with person 4 the e distance: 0.5477340160087432
# with person 5 the e distance: 0.6222918455944407
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-32unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.5009640889457374
# with person 2 the e distance: 0.42383728970509965
# with person 3 the e distance: 0.49797020090721694
# with person 4 the e distance: 0.5599276639645011
# with person 5 the e distance: 0.640692970910189
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-33unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.5060979992326807
# with person 2 the e distance: 0.411397357647688
# with person 3 the e distance: 0.47702436418162264
# with person 4 the e distance: 0.5562782785157139
# with person 5 the e distance: 0.636272474862498
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-33unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.5037916269138464
# with person 2 the e distance: 0.41259241052033335
# with person 3 the e distance: 0.4734135902876855
# with person 4 the e distance: 0.5532212394182475
# with person 5 the e distance: 0.6280294594245303
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-33unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.5144501913108304
# with person 2 the e distance: 0.4155808362521694
# with person 3 the e distance: 0.4799614537113631
# with person 4 the e distance: 0.5625344684053757
# with person 5 the e distance: 0.6264076654509052
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-34unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.503987423555115
# with person 2 the e distance: 0.4151490168653189
# with person 3 the e distance: 0.48638174073532053
# with person 4 the e distance: 0.5525550217639444
# with person 5 the e distance: 0.623483056148725
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-34unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.5108250486865402
# with person 2 the e distance: 0.41776899257952355
# with person 3 the e distance: 0.4700461482589462
# with person 4 the e distance: 0.5566099604862971
# with person 5 the e distance: 0.6179734202140301
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-34unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.5096370911506721
# with person 2 the e distance: 0.4227610754587139
# with person 3 the e distance: 0.4841744885068765
# with person 4 the e distance: 0.5622647797571765
# with person 5 the e distance: 0.6215870769024017
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-35unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.5241949490185819
# with person 2 the e distance: 0.4211369987537937
# with person 3 the e distance: 0.4976646811567577
# with person 4 the e distance: 0.5617520676276712
# with person 5 the e distance: 0.6404178352891023
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-35unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4979529146619569
# with person 2 the e distance: 0.41607279970500705
# with person 3 the e distance: 0.49249073185926384
# with person 4 the e distance: 0.5455994111394037
# with person 5 the e distance: 0.6274092409279122
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-36unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.49400682964111436
# with person 2 the e distance: 0.40399634771597837
# with person 3 the e distance: 0.48415976820783885
# with person 4 the e distance: 0.5462331236070966
# with person 5 the e distance: 0.6379650021550076
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-36unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.44035611866471014
# with person 2 the e distance: 0.3908413633893721
# with person 3 the e distance: 0.44257668890913954
# with person 4 the e distance: 0.4922719700730026
# with person 5 the e distance: 0.5925717749620781
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4765714414847349
# with person 2 the e distance: 0.4097764633568969
# with person 3 the e distance: 0.46768828083909403
# with person 4 the e distance: 0.5225735905147135
# with person 5 the e distance: 0.6030798399334178
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-37unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.44566133307518924
# with person 2 the e distance: 0.3957254466922465
# with person 3 the e distance: 0.4534915921291808
# with person 4 the e distance: 0.49738469097598514
# with person 5 the e distance: 0.599976454885996
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
# ##### camera person 1 #####
# with person 1 the e distance: 0.47166842282739446
# with person 2 the e distance: 0.40347856250762787
# with person 3 the e distance: 0.45856545131715554
# with person 4 the e distance: 0.5138904320317305
# with person 5 the e distance: 0.6039849081915817
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-38unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.46441679033553035
# with person 2 the e distance: 0.40148250577635397
# with person 3 the e distance: 0.4613964294326702
# with person 4 the e distance: 0.5111802123885074
# with person 5 the e distance: 0.6011825420577126
# Minimum e distance with person 2
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-03-38unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4554932344730134
# with person 2 the e distance: 0.3990837312193613
# with person 3 the e distance: 0.4533555117706328
# with person 4 the e distance: 0.5055949535804309
# with person 5 the e distance: 0.6098621584893634
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.45223859701899133
# with person 2 the e distance: 0.3952358213224607
# with person 3 the e distance: 0.46203289566713096
# with person 4 the e distance: 0.505220891785373
# with person 5 the e distance: 0.6056505404074009
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4300863086979958
# with person 2 the e distance: 0.38625702554154057
# with person 3 the e distance: 0.44404832581891696
# with person 4 the e distance: 0.4979243179252846
# with person 5 the e distance: 0.5902706757918761
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4139337373279098
# with person 2 the e distance: 0.3886084375186851
# with person 3 the e distance: 0.43409391385294815
# with person 4 the e distance: 0.48354651207417343
# with person 5 the e distance: 0.5755827008963669
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.40898466902254405
# with person 2 the e distance: 0.38915719816573535
# with person 3 the e distance: 0.4340257969302308
# with person 4 the e distance: 0.47868266613043786
# with person 5 the e distance: 0.5740798828547361
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3988239507646629
# with person 2 the e distance: 0.3789050312984037
# with person 3 the e distance: 0.42218160343946987
# with person 4 the e distance: 0.4671257261082336
# with person 5 the e distance: 0.5676250299000681
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4172177602534866
# with person 2 the e distance: 0.37766083545098983
# with person 3 the e distance: 0.4440504647845154
# with person 4 the e distance: 0.4757590520406734
# with person 5 the e distance: 0.5803898422057667
# Minimum e distance with person 2
# 重复，未保存！
#
#
# Faces in camera now: ['dilireba']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3882950112174981
# with person 2 the e distance: 0.39809621277577045
# with person 3 the e distance: 0.4098341860612616
# with person 4 the e distance: 0.46439492233013047
# with person 5 the e distance: 0.5478686943164578
# Minimum e distance with person 1
# 新存储：F:/picture/person/visitor/known/2021-11-13-21-03-41xiaozhan.jpg
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3881513245305093
# with person 2 the e distance: 0.39851229132749494
# with person 3 the e distance: 0.41370947058868
# with person 4 the e distance: 0.4655109465611295
# with person 5 the e distance: 0.5457570633572449
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3677579985663259
# with person 2 the e distance: 0.4556748157867584
# with person 3 the e distance: 0.40703983328775745
# with person 4 the e distance: 0.4296220168936493
# with person 5 the e distance: 0.5326529534915165
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35724282764023013
# with person 2 the e distance: 0.47689192350289117
# with person 3 the e distance: 0.4182210474507236
# with person 4 the e distance: 0.42354997302152125
# with person 5 the e distance: 0.5553277600200397
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.379726455254817
# with person 2 the e distance: 0.46758689834746275
# with person 3 the e distance: 0.41850649956293484
# with person 4 the e distance: 0.4557373796763561
# with person 5 the e distance: 0.564274570476231
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3693686966969361
# with person 2 the e distance: 0.46441372687703675
# with person 3 the e distance: 0.39853032253916
# with person 4 the e distance: 0.4284641324696269
# with person 5 the e distance: 0.5401041156486355
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['xiaozhan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3813586381249663
# with person 2 the e distance: 0.4706536123086714
# with person 3 the e distance: 0.40379944402717327
# with person 4 the e distance: 0.44258395377242554
# with person 5 the e distance: 0.5407001071631239
# Minimum e distance with person 1
# 重复，未保存！
#
#
# ...
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.650879333116311
# with person 2 the e distance: 0.6440116715410945
# with person 3 the e distance: 0.6219226355602404
# with person 4 the e distance: 0.6764209353364675
# with person 5 the e distance: 0.41913856238869573
# Minimum e distance with person 5
# Unknown person
# 新存储：F:/picture/person/visitor/unknown/2021-11-13-21-06-02unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
